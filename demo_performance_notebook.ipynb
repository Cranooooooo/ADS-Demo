# %%
import torch
import model
import os
import warnings

from dataloader import DataLoader
from misc import eval_utils
from opts import parse_opt
from misc.loss_wrapper import LossWrapper

warnings.filterwarnings('always')
opt = parse_opt()

# %%
# Test on all datasets
for illicit_name in ['Hack', 'Ransomware', 'Darknet']:
    # Load Data
    opt.illicit_name = illicit_name
    opt.id = opt.illicit_name
    split_loader = DataLoader(opt)

    # Load Model
    model_core = model.setup(opt)
    dp_lw_model = LossWrapper(model_core, opt)
    dp_lw_model.load_state_dict(torch.load(os.path.join(opt.start_from, f'{opt.illicit_name}.pth')))
    dp_lw_model = dp_lw_model.cuda()

    # Testing
    test_loss, test_metrics_score = eval_utils.eval_split(dp_lw_model, split_loader, split='test')

    # Clean up
    del dp_lw_model, model_core
# Out:
# Type: Hack --- Positive: 302 / Negative: 6582
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# 1364 test samples
# Evaluation loss is 0.6347374320030212
# ---------  Dataset Split test ---------
# -- Hour 1 : Accuracy: 0.9824 ; Precision: 0.7714 ; Recall: 0.871 ; F1: 0.8182 ; AUC: 0.9293 ;
# -- Hour 2 : Accuracy: 0.9824 ; Precision: 0.7568 ; Recall: 0.9032 ; F1: 0.8235 ; AUC: 0.9447 ;
# -- Hour 3 : Accuracy: 0.9795 ; Precision: 0.7179 ; Recall: 0.9032 ; F1: 0.8 ; AUC: 0.9432 ;
# -- Hour 4 : Accuracy: 0.978 ; Precision: 0.6905 ; Recall: 0.9355 ; F1: 0.7945 ; AUC: 0.9578 ;
# -- Hour 5 : Accuracy: 0.9765 ; Precision: 0.6744 ; Recall: 0.9355 ; F1: 0.7838 ; AUC: 0.957 ;
# -- Hour 6 : Accuracy: 0.9751 ; Precision: 0.6591 ; Recall: 0.9355 ; F1: 0.7733 ; AUC: 0.9562 ;
# -- Hour 7 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 8 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 9 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 10 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 11 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 12 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 13 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 14 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 15 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 16 : Accuracy: 0.978 ; Precision: 0.6818 ; Recall: 0.9677 ; F1: 0.8 ; AUC: 0.9731 ;
# -- Hour 14 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 15 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 16 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 17 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 18 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 19 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 20 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 21 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 22 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# -- Hour 23 : Accuracy: 0.9425 ; Precision: 0.7325 ; Recall: 0.9412 ; F1: 0.8238 ; AUC: 0.942 ;
# Avg Accuracy is 0.9393
# Avg Precision is 0.7223
# Avg Recall is 0.9414
# Early Weighed F1 is 0.8057758938117426 --------
# Consistency Score is 0.8213719427599125 --------
# Type: Darknet --- Positive: 5838 / Negative: 109937
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f88e86426a0>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# /home/user_cl/anaconda3/envs/btc_network/lib/python3.8/multiprocessing/popen_fork.py:70: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7f87eeed3220>
#   self.pid = os.fork()
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      12 dp_lw_model = dp_lw_model.cuda()
#      14 # Testing
# ---> 15 test_loss, test_metrics_score = eval_utils.eval_split(dp_lw_model, split_loader, split='test')
#      17 # Clean up
#      18 del dp_lw_model, model_core
#
# File ~/workplace_cl/btc_network/project_2_Fluidity_results/step_5_BTC_ED_work_1_path_tracer/Model_Expr_1/ADS_Demo/misc/eval_utils.py:85, in eval_split(dp_lw_model, loader, split)
#      81 dp_lw_model.model_core.split='test'
#      83 with torch.no_grad():
#      84     out, each_split_prediction, ground_labels = \
# ---> 85         dp_lw_model([AF_feat, fr_path_feat, bk_path_feat,
#      86                      fr_intersect_edge_batch, bk_intersect_edge_batch,
#      87                      fr_intersect_feat_batch, bk_intersect_feat_batch],
#      88                      labels, loss_amplify, return_pred_switch=True)
#      90 loss = out['total_loss']*bsz_used_downside
#      91 loss_sum = loss_sum + loss
#
# File ~/anaconda3/envs/btc_network/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/workplace_cl/btc_network/project_2_Fluidity_results/step_5_BTC_ED_work_1_path_tracer/Model_Expr_1/ADS_Demo/misc/loss_wrapper.py:143, in LossWrapper.forward(self, feats_list, labels, loss_amplify, return_pred_switch, epoch, iter, eval_switch)
#     139     this_split_bk_itsc_feat = feats_list[6][hour_index]
#     141     # input into model
#     142     former_hazard_list, predict_labels, AF_hidden, fr_Path_hidden, bk_Path_hidden, fr_Path_GCN_hidden, bk_Path_GCN_hidden, skip_list = \
# --> 143         self.model_core(this_split_AF_feat, AF_hidden,
#     144                         this_split_fr_path_feat, this_split_bk_path_feat, fr_Path_hidden, bk_Path_hidden,
#     145                         this_split_fr_itsc_edge, this_split_bk_itsc_edge, fr_Path_GCN_hidden, bk_Path_GCN_hidden,
#     146                         this_split_fr_itsc_feat, this_split_bk_itsc_feat,
#     147                         split_index=hour_index, former_hazard_list=former_hazard_list, skip_list=skip_list, prev_pred=prev_pred)
#     148     prev_pred = predict_labels
#     150 # Processing Metrics
#
# File ~/anaconda3/envs/btc_network/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/workplace_cl/btc_network/project_2_Fluidity_results/step_5_BTC_ED_work_1_path_tracer/Model_Expr_1/ADS_Demo/model/model.py:399, in E_Path_Tracer.forward(self, AF_feat, AF_hidden, fr_path_feat, bk_path_feat, fr_Path_hidden, bk_Path_hidden, fr_itsc_edge, bk_itsc_edge, fr_Graph_hidden, bk_Graph_hidden, fr_itsc_feat, bk_itsc_feat, split_index, former_hazard_list, skip_list, prev_pred)
#     394 fr_h_t, bk_h_t, h_global_fr_path, h_global_bk_path, fr_Path_hidden, bk_Path_hidden = \
#     395     self.path_process(bsz, h_global_AF, fr_path_feat, bk_path_feat, fr_Path_hidden, bk_Path_hidden)
#     397 # 3. Path-GCN
#     398 h_global_fr_graph, h_global_bk_graph, fr_Graph_hidden, bk_Graph_hidden, skip_list = \
# --> 399     self.graph_process(bsz, h_global_AF, fr_h_t, bk_h_t, fr_itsc_feat, bk_itsc_feat,
#     400                        fr_itsc_edge, bk_itsc_edge, fr_Graph_hidden, bk_Graph_hidden,
#     401                        former_hazard_list, split_index, skip_list)
#     403 # 4. Prediction
#     404 # 4.1 Calculate each rate
#     405 rate_weight = self.rate_weight(h_global_fr_path)
#
# File ~/workplace_cl/btc_network/project_2_Fluidity_results/step_5_BTC_ED_work_1_path_tracer/Model_Expr_1/ADS_Demo/model/model.py:351, in E_Path_Tracer.graph_process(self, bsz, h_global_AF, fr_h_t, bk_h_t, fr_itsc_feat, bk_itsc_feat, fr_itsc_edge, bk_itsc_edge, fr_Graph_hidden, bk_Graph_hidden, former_hazard_list, split_index, skip_list, prev_predict)
#     349     if this_bk_itsc_feat.shape[0] == 0: continue
#     350     else:
# --> 351         intsced_bk_path = self.bk_Path_GCN(bk_h_t[addr_idx, :, :], this_bk_itsc_feat, this_bk_itsc_edge,
#     352                                            bk_intsc_feat_fc[addr_idx, :, :], bk_messageNN[addr_idx, :, :], bk_updateNN[addr_idx, :, :])
#     353     bk_h_t_insect[addr_idx, :, :] = intsced_bk_path
#     357 # 3.2 Attention
#
# File ~/anaconda3/envs/btc_network/lib/python3.8/site-packages/torch/nn/modules/module.py:1130, in Module._call_impl(self, *input, **kwargs)
#    1126 # If we don't have any hooks, we want to skip the rest of the logic in
#    1127 # this function, and just call forward.
#    1128 if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130     return forward_call(*input, **kwargs)
#    1131 # Do not call functions when jit is used
#    1132 full_backward_hooks, non_full_backward_hooks = [], []
#
# File ~/workplace_cl/btc_network/project_2_Fluidity_results/step_5_BTC_ED_work_1_path_tracer/Model_Expr_1/ADS_Demo/model/misc_model/Evo_Path_GCN.py:64, in Evo_Path_GNN.forward(self, node_feat, edge_feat, edge_list, intsc_feat_fc, messageNN, updateNN)
#      62     # Update Sink
#      63     update_message = 1./sink_degree*torch.matmul(messageNN, edge_feat[edge_idx,:])*node_feat[source, :]
# ---> 64     update_node_feat[sink, :] = torch.matmul(update_node_feat[sink, :] + update_message, updateNN)
#      66 return node_feat
#
# KeyboardInterrupt:
